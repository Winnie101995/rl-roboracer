# %% [markdown]
# # COMP47590 Advanced Machine Learning Final

# %% [markdown]
# #### Student Name: Winnie Imafidon
# #### Student Number: 2220023

# %% [markdown]
# ## Assignment 2: Going the Distance
# Uses the PPO actor-critic method to train a neural network to control a simple robot in the RacingCar environment from OpenAI gym (https://gym.openai.com/envs/RacingCar-v0/).

# %% [markdown]
# ![Racing](racing_car.gif)
#
# The **action** space can be continuous or discreet. If **continuous** there are 3 actions :
#
# - 0: steering, -1 is full left, +1 is full right
# - 1: gas
# - 2: breaking
#
# If **discrete** there are 5 actions:
# - 0: do nothing
# - 1: steer left
# - 2: steer right
# - 3: gas
# - 4: brake
#
# For this assignment we should use the continuous action space.
#
# **Reward** of -0.1 is awarded every frame and +1000/N for every track tile visited, where N is the total number of tiles in track. For example, if you have finished in 732 frames, your reward is 1000 - 0.1*732 = 926.8 points.
#
# And the default **observation** is a single image frame (96 * 96).

# %% [markdown]
# ### Initialisation

# %% [markdown]
# If using Google colab you need to install packages - comment out lines below.

# %%
#!apt install swig cmake ffmpeg
#!apt-get install -y xvfb x11-utils
#!pip install stable-baselines3[extra] pyglet box2d box2d-kengz
#!pip install pyvirtualdisplay PyOpenGL PyOpenGL-accelerate

# %% [markdown]
# For Google colab comment out this cell to make a virtual rendering canvas so render calls work (we still won't see display!)

# %%
#import pyvirtualdisplay
#
#_display = pyvirtualdisplay.Display(visible=False,  # use False with Xvfb
#                                    size=(1400, 900))
#_ = _display.start()

# %% [markdown]
# Import required packages.

# %%
import torch 
import gymnasium as gym
import stable_baselines3 as sb3

import pandas as pd # For data frames and data frame manipulation
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)
import numpy as np # For general  numeric operations

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Create and Explore the Environment

# %% [markdown]
# Create the **CarRacing-v2** environment. Add wrappers to resize the images and convert to greyscale.

# %%
env = gym.make('CarRacing-v2', 
               render_mode = 'human')
#  useful for reducing the input dimensionality for a machine learning model, which can speed up training.
env = gym.wrappers.resize_observation.ResizeObservation(env, 64)
# This wrapper converts RGB images to grayscale, which simplifies the 
# learning task by reducing the color information that the model needs to process. 
env = gym.wrappers.gray_scale_observation.GrayScaleObservation(env, keep_dim = True)
# This wrapper limits the number of steps in each episode to 1500, after which the episode will automatically end.
env = gym.wrappers.TimeLimit(env, 
                                max_episode_steps = 1500)

# %% [markdown]
# Explore the environment - view the action space and observation space.

# %%
env.action_space
# Out:
# Box([-1.  0.  0.], 1.0, (3,), float32)

# %%
env.observation_space
# Out:
# Box(0, 255, (64, 64, 1), uint8)

# %%
# highlighting that this is a continuous action space 
action = env.action_space.sample()
print(action)
# Out:
# [0.9162945  0.2870367  0.03831504]

# %% [markdown]
# Play an episode of the environment using random actions

# %%
episodes = 1
for episode in range(1, episodes+1):
    obs , _ = env.reset()
    score = 0
    done = False
    truncate = False
    while not done:    
        action = env.action_space.sample()
        obs, reward, done, truncate, info = env.step(action)
        score += reward         
        env.render()
        
    print("Episode:{} Score:{}".format(episode,score))
env.close()
# Out:
# Episode:1 Score:-497.64814814817026

# %%
print(reward)
# Out:
# -100

# %%
print(action)
# Out:
# [-0.512909    0.24843697  0.548837  ]

# %% [markdown]
# ### Single Image Agent
# Create an agent that controls the car using a single image frame as the state input. We recommend a PPO agent with the following hyper-parameters (although you can experiment):
# - learning_rate = 3e-5
# - n_steps = 512
# - ent_coef = 0.001
# - batch_size = 128
# - gae_lambda =  0.9
# - n_epochs = 20
# - use_sde = True
# - sde_sample_freq = 4
# - clip_range = 0.4
# - policy_kwargs = {'log_std_init': -2, 'ortho_init':False},
#
# We also recommend enabling **tensorboard** monitoring of the training process.

# %%
network_args = {'log_std_init': -2, 'ortho_init':False}

# %%
env_train = gym.make('CarRacing-v2')
env_train = gym.wrappers.resize_observation.ResizeObservation(env_train, 64)
env_train = gym.wrappers.gray_scale_observation.GrayScaleObservation(env_train, keep_dim = True)

# %%
tb_log = './log_tb_carracing_ppo_final1/'
ppo_agent_model = sb3.PPO('CnnPolicy', 
                env_train, 
                learning_rate = 0.00003,
                n_steps = 512,
                batch_size = 128,
                ent_coef = 0.001,
                gae_lambda = 0.9,
                n_epochs = 20,
                use_sde = True,
                sde_sample_freq = 4,
                clip_range = 0.4,
                verbose=1,
                policy_kwargs = network_args,
                tensorboard_log=tb_log
              )
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# Examine the actor and critic network architectures.

# %%
print(ppo_agent_model.policy)
# Out:
# ActorCriticCnnPolicy(
#   (features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (pi_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (vf_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(1, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential()
#     (value_net): Sequential()
#   )
#   (action_net): Linear(in_features=512, out_features=3, bias=True)
#   (value_net): Linear(in_features=512, out_features=1, bias=True)
# )

# %% [markdown]
# Create an evaluation callback that is called every at regular intervals and renders the episode.

# %%
# ensuring the environments are the same for training
eval_env = ppo_agent_model.get_env()

# %%
# another way to male envionmnt 
# eval_env = gym.make('CarRacing-v2', render_mode = 'human') # We use a separate evaluation env in case any wrappers have been used
# eval_env = gym.wrappers.resize_observation.ResizeObservation(eval_env, 64)
# # This wrapper converts RGB images to grayscale, which simplifies the 
# # learning task by reducing the color information that the model needs to process. 
# eval_env = gym.wrappers.gray_scale_observation.GrayScaleObservation(eval_env, keep_dim = True)

# %%
eval_callback = sb3.common.callbacks.EvalCallback(eval_env, 
                                                  log_path= './logs_carracing_final1/', 
                                                  eval_freq=5000,
                                                  render=False)

# %% [markdown]
# Train the model for a large number of timesteps (500,000 timesteps will probably work well).

# %%
eval_env.observation_space
# Out:
# Box(0, 255, (1, 64, 64), uint8)

# %%
eval_env.action_space
# Out:
# Box([-1.  0.  0.], 1.0, (3,), float32)

# %%
# # Add code here
ppo_agent_model.learn(total_timesteps=500000,
            callback=eval_callback,
            tb_log_name="ppo_carracing_final"
           )

# %% [markdown]
# Connect to the tensorboard log using **TensorBoard** from the command line to view training progress:
#
# `tensorboard --logdir ./logs_carracing_ppo_final1/`
#
# Then open TensorBoard in a browser, typically located at:
#
# `http://localhost:6006/`

# %% [markdown]
# Save the trained agent.

# %%
# %load_ext tensorboard

# %%
# please see ppo_carracing_final_1
# %tensorboard --logdir ./log_tb_carracing_ppo_final1/
# Out:
#       <iframe id="tensorboard-frame-dc96bd3ec4de4de3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dc96bd3ec4de4de3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
ppo_agent_model.save("./carracingPPO_agent")

# %% [markdown]
# For memory management delete old agent and environment (assumes variable names - change if required).

# %%
del ppo_agent_model
del env
del eval_env

# %% [markdown]
# ### Create Image Stack Agent

# %% [markdown]
# Create the CarRacing-v0 environment using wrappers to resize the images to 64 x 64 and change to greyscale. Also add a wrapper to create a stack of 4 frames.

# %%
# Add code here
# Add code here
env = gym.make('CarRacing-v2', render_mode = 'human')

#  useful for reducing the input dimensionality for a machine learning model, which can speed up training.
env = gym.wrappers.resize_observation.ResizeObservation(env, 64)
# This wrapper converts RGB images to grayscale, which simplifies the 
# learning task by reducing the color information that the model needs to process. 
env = gym.wrappers.gray_scale_observation.GrayScaleObservation(env, keep_dim = True)
env  = sb3.common.monitor.Monitor(env)
env= sb3.common.vec_env.DummyVecEnv([lambda: env])
env = sb3.common.vec_env.VecFrameStack(env, 
                                       n_stack=4)
env = gym.wrappers.TimeLimit(env, 
                                max_episode_steps = 1500)

# %%
env.action_space
# Out:
# Box([-1.  0.  0.], 1.0, (3,), float32)

# %%
env.observation_space
# Out:
# Box(0, 255, (64, 64, 4), uint8)

# %% [markdown]
# Create an agent that controls the car using a stack of input image frames as the state input. We recommend a PPO agent with the following hyper-parameters (although you can experiment):
# - learning_rate = 3e-5
# - n_steps = 512
# - ent_coef = 0.001
# - batch_size = 128
# - gae_lambda =  0.9
# - n_epochs = 20
# - use_sde = True
# - sde_sample_freq = 4
# - clip_range = 0.4
# - policy_kwargs = {'log_std_init': -2, 'ortho_init':False},
#
# We also recommend enabling **tensorboard** monitoring of the training process.

# %%
env_train_stack = gym.make('CarRacing-v2')
env_train_stack = gym.wrappers.resize_observation.ResizeObservation(env_train_stack, 64)
env_train_stack = gym.wrappers.gray_scale_observation.GrayScaleObservation(env_train_stack, keep_dim = True)
env_train_stack = sb3.common.monitor.Monitor(env_train_stack)
env_train_stack = sb3.common.vec_env.DummyVecEnv([lambda: env_train_stack])
env_train_stack = sb3.common.vec_env.VecFrameStack(env_train_stack, 
                                       n_stack=4)

# %%
# Add code here
tb_log = './log_tb_carracing_task2_final1/'
ppo_agent_model = sb3.PPO('CnnPolicy', 
                env_train_stack, 
                learning_rate = 0.00003,
                n_steps = 512,
                ent_coef = 0.001,
                batch_size = 128,
                gae_lambda = 0.9,
                n_epochs = 20,
                use_sde = True,
                sde_sample_freq = 4,
                clip_range = 0.4,
                verbose=1,
                policy_kwargs = network_args,
                tensorboard_log=tb_log
              )
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# Examine the actor and critic network architectures.

# %%
# Add code here
print(ppo_agent_model.policy)
# Out:
# ActorCriticCnnPolicy(
#   (features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (pi_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (vf_features_extractor): NatureCNN(
#     (cnn): Sequential(
#       (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#       (1): ReLU()
#       (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#       (3): ReLU()
#       (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#       (5): ReLU()
#       (6): Flatten(start_dim=1, end_dim=-1)
#     )
#     (linear): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): ReLU()
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential()
#     (value_net): Sequential()
#   )
#   (action_net): Linear(in_features=512, out_features=3, bias=True)
#   (value_net): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
eval_env = ppo_agent_model.get_env()

# %%
# # Add code here
#Another way tomkae eval env 
# eval_env = gym.make('CarRacing-v2', render_mode = 'human') # We use a separate evaluation env in case any wrappers have been used
# eval_env = gym.wrappers.resize_observation.ResizeObservation(eval_env, 64)
# eval_env = gym.wrappers.gray_scale_observation.GrayScaleObservation(eval_env, keep_dim = True)
# eval_env = sb3.common.monitor.Monitor(eval_env)
# eval_env = sb3.common.vec_env.DummyVecEnv([lambda: eval_env])
# eval_env = sb3.common.vec_env.VecFrameStack(eval_env, 
#                                        n_stack=4)

# %% [markdown]
# Create an evaluation callback that is called every at regular intervals and renders the episode.

# %%
# Add code here
eval_callback = sb3.common.callbacks.EvalCallback(eval_env, 
                                                  log_path= './logs_carracing_task2/_final1', 
                                                  eval_freq= 5000,
                                                  render=False)

# %% [markdown]
# Train the model for a large number of timesteps (500,000 timesteps will probably work well).

# %%
# Add code here
ppo_agent_model.learn(total_timesteps=500000,
            callback=eval_callback,
            tb_log_name="ppo_carracing_task2_final1"
           )
# Out:
# Logging to ./log_tb_carracing_task2_final1/ppo_carracing_task2_final1_4
# ----------------------------
# | time/              |     |
# |    fps             | 150 |
# |    iterations      | 1   |
# |    time_elapsed    | 3   |
# |    total_timesteps | 512 |
# ----------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -59.9    |
# | time/                   |          |
# |    fps                  | 77       |
# |    iterations           | 2        |
# |    time_elapsed         | 13       |
# |    total_timesteps      | 1024     |
# | train/                  |          |
# |    approx_kl            | 2.923398 |
# |    clip_fraction        | 0.724    |
# |    clip_range           | 0.4      |
# |    entropy_loss         | 1.55     |
# |    explained_variance   | 0.000187 |
# |    learning_rate        | 3e-05    |
# |    loss                 | 0.364    |
# |    n_updates            | 20       |
# |    policy_gradient_loss | 0.0915   |
# |    std                  | 0.135    |
# |    value_loss           | 0.757    |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -59.9    |
# | time/                   |          |
# |    fps                  | 66       |
# |    iterations           | 3        |
# |    time_elapsed         | 23       |
# |    total_timesteps      | 1536     |
# | train/                  |          |
# |    approx_kl            | 1.470951 |
# |    clip_fraction        | 0.743    |
# |    clip_range           | 0.4      |
# |    entropy_loss         | -2.87    |
# |    explained_variance   | 0.0627   |
# |    learning_rate        | 3e-05    |
# |    loss                 | 0.215    |
# |    n_updates            | 40       |
# |    policy_gradient_loss | 0.101    |
# |    std                  | 0.135    |
# |    value_loss           | 0.702    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -67.6      |
# | time/                   |            |
# |    fps                  | 61         |
# |    iterations           | 4          |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 2048       |
# | train/                  |            |
# |    approx_kl            | 0.24303502 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -4.46      |
# |    explained_variance   | 0.138      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.222      |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.0442     |
# |    std                  | 0.135      |
# |    value_loss           | 0.435      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -67.6       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 5           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.097215675 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.049       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.135       |
# |    value_loss           | 0.204       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -67.2      |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 6          |
# |    time_elapsed         | 52         |
# |    total_timesteps      | 3072       |
# | train/                  |            |
# |    approx_kl            | 0.09478405 |
# |    clip_fraction        | 0.26       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -5.2       |
# |    explained_variance   | 0.335      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.213      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00258   |
# |    std                  | 0.135      |
# |    value_loss           | 0.55       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -67.2       |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 7           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.051653095 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -5.74       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.0314      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 0.135       |
# |    value_loss           | 0.295       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.8      |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 8          |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.09170626 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -5.82      |
# |    explained_variance   | 0.646      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.337      |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0393    |
# |    std                  | 0.135      |
# |    value_loss           | 1.01       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -60.8       |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 9           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.045446113 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -6.32       |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.256       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.135       |
# |    value_loss           | 1.25        |
# -----------------------------------------
# Eval num_timesteps=5000, episode_reward=-82.39 +/- 1.42
# Episode length: 1000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1e+03      |
# |    mean_reward          | -82.4      |
# | time/                   |            |
# |    total_timesteps      | 5000       |
# | train/                  |            |
# |    approx_kl            | 0.06345214 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -6.97      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.0805    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0361    |
# |    std                  | 0.135      |
# |    value_loss           | 0.0284     |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -56.5    |
# | time/              |          |
# |    fps             | 40       |
# |    iterations      | 10       |
# |    time_elapsed    | 125      |
# |    total_timesteps | 5120     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -56.5      |
# | time/                   |            |
# |    fps                  | 41         |
# |    iterations           | 11         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.05519409 |
# |    clip_fraction        | 0.0854     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -6.77      |
# |    explained_variance   | 0.715      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.383      |
# |    n_updates            | 200        |
# |    policy_gradient_loss | 0.00636    |
# |    std                  | 0.135      |
# |    value_loss           | 1.04       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.2      |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 12         |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.07180928 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.49      |
# |    explained_variance   | 0.555      |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.0544    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0457    |
# |    std                  | 0.135      |
# |    value_loss           | 0.0599     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.2      |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 13         |
# |    time_elapsed         | 155        |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.04928028 |
# |    clip_fraction        | 0.0921     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.36      |
# |    explained_variance   | 0.658      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.148      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0428    |
# |    std                  | 0.135      |
# |    value_loss           | 0.529      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.8      |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 14         |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.03927673 |
# |    clip_fraction        | 0.0651     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.68      |
# |    explained_variance   | 0.702      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.213      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0279    |
# |    std                  | 0.135      |
# |    value_loss           | 0.422      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.8      |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 15         |
# |    time_elapsed         | 175        |
# |    total_timesteps      | 7680       |
# | train/                  |            |
# |    approx_kl            | 0.06598094 |
# |    clip_fraction        | 0.0991     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.08      |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.267      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.00166    |
# |    std                  | 0.135      |
# |    value_loss           | 0.847      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -61.2      |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 16         |
# |    time_elapsed         | 185        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.06311238 |
# |    clip_fraction        | 0.152      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.3       |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.0107    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0419    |
# |    std                  | 0.135      |
# |    value_loss           | 0.0507     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -61.2      |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 17         |
# |    time_elapsed         | 195        |
# |    total_timesteps      | 8704       |
# | train/                  |            |
# |    approx_kl            | 0.03569882 |
# |    clip_fraction        | 0.0878     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.07      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.33       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.039     |
# |    std                  | 0.134      |
# |    value_loss           | 0.813      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.9      |
# | time/                   |            |
# |    fps                  | 44         |
# |    iterations           | 18         |
# |    time_elapsed         | 205        |
# |    total_timesteps      | 9216       |
# | train/                  |            |
# |    approx_kl            | 0.03060849 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.23      |
# |    explained_variance   | 0.853      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.00291    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0298    |
# |    std                  | 0.134      |
# |    value_loss           | 0.0755     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -60.9      |
# | time/                   |            |
# |    fps                  | 45         |
# |    iterations           | 19         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 9728       |
# | train/                  |            |
# |    approx_kl            | 0.07826886 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.98      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.278      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0431    |
# |    std                  | 0.134      |
# |    value_loss           | 0.878      |
# ----------------------------------------
# Eval num_timesteps=10000, episode_reward=-82.83 +/- 1.92
# Episode length: 1000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1e+03      |
# |    mean_reward          | -82.8      |
# | time/                   |            |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.05704789 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.32      |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.073     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0425    |
# |    std                  | 0.134      |
# |    value_loss           | 0.0345     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -61.8    |
# | time/              |          |
# |    fps             | 38       |
# |    iterations      | 20       |
# |    time_elapsed    | 263      |
# |    total_timesteps | 10240    |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -61.8     |
# | time/                   |           |
# |    fps                  | 39        |
# |    iterations           | 21        |
# |    time_elapsed         | 273       |
# |    total_timesteps      | 10752     |
# | train/                  |           |
# |    approx_kl            | 0.0424335 |
# |    clip_fraction        | 0.106     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -7.95     |
# |    explained_variance   | 0.871     |
# |    learning_rate        | 3e-05     |
# |    loss                 | 0.345     |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.0487   |
# |    std                  | 0.134     |
# |    value_loss           | 0.742     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -61.9      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 22         |
# |    time_elapsed         | 283        |
# |    total_timesteps      | 11264      |
# | train/                  |            |
# |    approx_kl            | 0.06515707 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.98      |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.0594    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0527    |
# |    std                  | 0.134      |
# |    value_loss           | 0.0385     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -61.9      |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 23         |
# |    time_elapsed         | 294        |
# |    total_timesteps      | 11776      |
# | train/                  |            |
# |    approx_kl            | 0.08462958 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -7.56      |
# |    explained_variance   | 0.843      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.467      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0476    |
# |    std                  | 0.134      |
# |    value_loss           | 1.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -62         |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 24          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.063074246 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -7.77       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.116       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 0.134       |
# |    value_loss           | 0.436       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -62        |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 25         |
# |    time_elapsed         | 314        |
# |    total_timesteps      | 12800      |
# | train/                  |            |
# |    approx_kl            | 0.07710482 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.38      |
# |    explained_variance   | 0.825      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.0577     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0405    |
# |    std                  | 0.134      |
# |    value_loss           | 0.719      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.4       |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 26          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.068893395 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.54       |
# |    explained_variance   | 0.191       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0208     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.032      |
# |    std                  | 0.134       |
# |    value_loss           | 0.0704      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -63.4      |
# | time/                   |            |
# |    fps                  | 41         |
# |    iterations           | 27         |
# |    time_elapsed         | 335        |
# |    total_timesteps      | 13824      |
# | train/                  |            |
# |    approx_kl            | 0.04938163 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.32      |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.252      |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0271    |
# |    std                  | 0.134      |
# |    value_loss           | 0.598      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.6       |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 28          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.084420785 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.51       |
# |    explained_variance   | 0.538       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0287     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0412     |
# |    std                  | 0.134       |
# |    value_loss           | 0.0581      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -63.6       |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 29          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.071145386 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.004       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0385     |
# |    std                  | 0.134       |
# |    value_loss           | 0.268       |
# -----------------------------------------
# Eval num_timesteps=15000, episode_reward=-83.74 +/- 1.18
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -83.7       |
# | time/                   |             |
# |    total_timesteps      | 15000       |
# | train/                  |             |
# |    approx_kl            | 0.052612588 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.59       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0492     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.134       |
# |    value_loss           | 0.0176      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -64.7    |
# | time/              |          |
# |    fps             | 37       |
# |    iterations      | 30       |
# |    time_elapsed    | 404      |
# |    total_timesteps | 15360    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -64.7      |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 31         |
# |    time_elapsed         | 414        |
# |    total_timesteps      | 15872      |
# | train/                  |            |
# |    approx_kl            | 0.06098421 |
# |    clip_fraction        | 0.122      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.4       |
# |    explained_variance   | 0.889      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.0535     |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0244    |
# |    std                  | 0.134      |
# |    value_loss           | 0.242      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -65.3      |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 32         |
# |    time_elapsed         | 425        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.13381507 |
# |    clip_fraction        | 0.35       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.5       |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.0152    |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0519    |
# |    std                  | 0.134      |
# |    value_loss           | 0.256      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -65.3      |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 33         |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 16896      |
# | train/                  |            |
# |    approx_kl            | 0.03423026 |
# |    clip_fraction        | 0.0592     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.48      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.155      |
# |    n_updates            | 640        |
# |    policy_gradient_loss | 0.00111    |
# |    std                  | 0.134      |
# |    value_loss           | 0.421      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -65.5       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 34          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.042859644 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.81       |
# |    explained_variance   | 0.668       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.113       |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.134       |
# |    value_loss           | 0.404       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -65.5      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 35         |
# |    time_elapsed         | 456        |
# |    total_timesteps      | 17920      |
# | train/                  |            |
# |    approx_kl            | 0.07237867 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.73      |
# |    explained_variance   | 0.827      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.103      |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.0283    |
# |    std                  | 0.134      |
# |    value_loss           | 0.387      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -66.4       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 36          |
# |    time_elapsed         | 466         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.029028118 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.84       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0127     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.134       |
# |    value_loss           | 0.0211      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -66.4       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 37          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 18944       |
# | train/                  |             |
# |    approx_kl            | 0.011782528 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.57       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.0276      |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0208     |
# |    std                  | 0.134       |
# |    value_loss           | 0.217       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -66.9       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 38          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.044034965 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.62       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.044       |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.134       |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -66.9      |
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 39         |
# |    time_elapsed         | 497        |
# |    total_timesteps      | 19968      |
# | train/                  |            |
# |    approx_kl            | 0.07860741 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.87      |
# |    explained_variance   | 0.875      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.036      |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.0498    |
# |    std                  | 0.134      |
# |    value_loss           | 0.231      |
# ----------------------------------------
# Eval num_timesteps=20000, episode_reward=-81.81 +/- 1.68
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -81.8       |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.026129756 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -9.12       |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.00786    |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.134       |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -67.7    |
# | time/              |          |
# |    fps             | 37       |
# |    iterations      | 40       |
# |    time_elapsed    | 545      |
# |    total_timesteps | 20480    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -67.7       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 41          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 20992       |
# | train/                  |             |
# |    approx_kl            | 0.043998174 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.53       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.658       |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0422     |
# |    std                  | 0.134       |
# |    value_loss           | 1.88        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -66.5      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 42         |
# |    time_elapsed         | 566        |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.08813766 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -8.57      |
# |    explained_variance   | 0.891      |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.0115    |
# |    n_updates            | 820        |
# |    policy_gradient_loss | -0.0509    |
# |    std                  | 0.134      |
# |    value_loss           | 0.255      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.9       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 43          |
# |    time_elapsed         | 577         |
# |    total_timesteps      | 22016       |
# | train/                  |             |
# |    approx_kl            | 0.057361938 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.48       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.781       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.134       |
# |    value_loss           | 2.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.9       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 44          |
# |    time_elapsed         | 588         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.052848373 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.77       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.768       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.134       |
# |    value_loss           | 2.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.7       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 45          |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.042803094 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -8.91       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.618       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0438     |
# |    std                  | 0.134       |
# |    value_loss           | 2.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.7       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 46          |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.010718496 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -9.34       |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.223       |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.000426   |
# |    std                  | 0.134       |
# |    value_loss           | 1.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -62.5       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 47          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 24064       |
# | train/                  |             |
# |    approx_kl            | 0.038062584 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -9.59       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 3e-05       |
# |    loss                 | -0.0123     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00452    |
# |    std                  | 0.134       |
# |    value_loss           | 0.0758      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -62.5       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 48          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.099915765 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -9.92       |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.127       |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00623    |
# |    std                  | 0.134       |
# |    value_loss           | 1.07        |
# -----------------------------------------
# Eval num_timesteps=25000, episode_reward=-84.84 +/- 0.81
# Episode length: 1000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1e+03      |
# |    mean_reward          | -84.8      |
# | time/                   |            |
# |    total_timesteps      | 25000      |
# | train/                  |            |
# |    approx_kl            | 0.10400417 |
# |    clip_fraction        | 0.31       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -9.62      |
# |    explained_variance   | 0.605      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.565      |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0503    |
# |    std                  | 0.134      |
# |    value_loss           | 1.43       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -61.5    |
# | time/              |          |
# |    fps             | 36       |
# |    iterations      | 49       |
# |    time_elapsed    | 680      |
# |    total_timesteps | 25088    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.5       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 50          |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.051522814 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -9.82       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.282       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.0078     |
# |    std                  | 0.134       |
# |    value_loss           | 0.464       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -61.7       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 51          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 26112       |
# | train/                  |             |
# |    approx_kl            | 0.054529462 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -10         |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.116       |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.134       |
# |    value_loss           | 0.283       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -61.7      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 52         |
# |    time_elapsed         | 711        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.13078502 |
# |    clip_fraction        | 0.341      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -10.3      |
# |    explained_variance   | 0.791      |
# |    learning_rate        | 3e-05      |
# ...
# |    fps                  | 28         |
# |    iterations           | 961        |
# |    time_elapsed         | 16974      |
# |    total_timesteps      | 492032     |
# | train/                  |            |
# |    approx_kl            | 0.01983035 |
# |    clip_fraction        | 0.0615     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -17.6      |
# |    explained_variance   | -0.536     |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.174      |
# |    n_updates            | 19200      |
# |    policy_gradient_loss | -0.0145    |
# |    std                  | 0.131      |
# |    value_loss           | 2.13       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 997        |
# |    ep_rew_mean          | -70.2      |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 962        |
# |    time_elapsed         | 16985      |
# |    total_timesteps      | 492544     |
# | train/                  |            |
# |    approx_kl            | 0.07569144 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -17.5      |
# |    explained_variance   | 0.431      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.706      |
# |    n_updates            | 19220      |
# |    policy_gradient_loss | -0.0257    |
# |    std                  | 0.131      |
# |    value_loss           | 2.74       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 997        |
# |    ep_rew_mean          | -70        |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 963        |
# |    time_elapsed         | 16996      |
# |    total_timesteps      | 493056     |
# | train/                  |            |
# |    approx_kl            | 0.02337089 |
# |    clip_fraction        | 0.0436     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -17.8      |
# |    explained_variance   | 0.0134     |
# |    learning_rate        | 3e-05      |
# |    loss                 | -0.0105    |
# |    n_updates            | 19240      |
# |    policy_gradient_loss | -0.0242    |
# |    std                  | 0.131      |
# |    value_loss           | 0.196      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -70         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 964         |
# |    time_elapsed         | 17008       |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.041776303 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.604       |
# |    n_updates            | 19260       |
# |    policy_gradient_loss | 0.00212     |
# |    std                  | 0.131       |
# |    value_loss           | 1.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -69.2       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 965         |
# |    time_elapsed         | 17019       |
# |    total_timesteps      | 494080      |
# | train/                  |             |
# |    approx_kl            | 0.030338146 |
# |    clip_fraction        | 0.0161      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.01        |
# |    n_updates            | 19280       |
# |    policy_gradient_loss | -0.00689    |
# |    std                  | 0.131       |
# |    value_loss           | 1.93        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 997        |
# |    ep_rew_mean          | -69.2      |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 966        |
# |    time_elapsed         | 17030      |
# |    total_timesteps      | 494592     |
# | train/                  |            |
# |    approx_kl            | 0.06005353 |
# |    clip_fraction        | 0.0959     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -17.5      |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.208      |
# |    n_updates            | 19300      |
# |    policy_gradient_loss | -0.0496    |
# |    std                  | 0.131      |
# |    value_loss           | 0.792      |
# ----------------------------------------
# Eval num_timesteps=495000, episode_reward=-68.61 +/- 1.25
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -68.6       |
# | time/                   |             |
# |    total_timesteps      | 495000      |
# | train/                  |             |
# |    approx_kl            | 0.012064287 |
# |    clip_fraction        | 0.00215     |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.87        |
# |    n_updates            | 19320       |
# |    policy_gradient_loss | -0.00585    |
# |    std                  | 0.131       |
# |    value_loss           | 1.2         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 997      |
# |    ep_rew_mean     | -69      |
# | time/              |          |
# |    fps             | 28       |
# |    iterations      | 967      |
# |    time_elapsed    | 17083    |
# |    total_timesteps | 495104   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 997        |
# |    ep_rew_mean          | -69        |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 968        |
# |    time_elapsed         | 17094      |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.04208316 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -17.3      |
# |    explained_variance   | 0.655      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 1.08       |
# |    n_updates            | 19340      |
# |    policy_gradient_loss | -0.0214    |
# |    std                  | 0.131      |
# |    value_loss           | 3.72       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -68.9       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 969         |
# |    time_elapsed         | 17106       |
# |    total_timesteps      | 496128      |
# | train/                  |             |
# |    approx_kl            | 0.019132549 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.3       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.28        |
# |    n_updates            | 19360       |
# |    policy_gradient_loss | -0.0218     |
# |    std                  | 0.131       |
# |    value_loss           | 1.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -68.9       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 970         |
# |    time_elapsed         | 17117       |
# |    total_timesteps      | 496640      |
# | train/                  |             |
# |    approx_kl            | 0.027984524 |
# |    clip_fraction        | 0.0635      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.125       |
# |    n_updates            | 19380       |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.131       |
# |    value_loss           | 0.587       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -68.3       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 971         |
# |    time_elapsed         | 17128       |
# |    total_timesteps      | 497152      |
# | train/                  |             |
# |    approx_kl            | 0.006873468 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.518       |
# |    n_updates            | 19400       |
# |    policy_gradient_loss | -0.00585    |
# |    std                  | 0.131       |
# |    value_loss           | 1.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -68.3       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 972         |
# |    time_elapsed         | 17140       |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.023396099 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.6       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.204       |
# |    n_updates            | 19420       |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.131       |
# |    value_loss           | 0.935       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 997        |
# |    ep_rew_mean          | -67.6      |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 973        |
# |    time_elapsed         | 17151      |
# |    total_timesteps      | 498176     |
# | train/                  |            |
# |    approx_kl            | 0.08760332 |
# |    clip_fraction        | 0.343      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -17.1      |
# |    explained_variance   | 0.709      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.804      |
# |    n_updates            | 19440      |
# |    policy_gradient_loss | -0.0491    |
# |    std                  | 0.131      |
# |    value_loss           | 1.85       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -67.6       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 974         |
# |    time_elapsed         | 17162       |
# |    total_timesteps      | 498688      |
# | train/                  |             |
# |    approx_kl            | 0.033731107 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.17        |
# |    n_updates            | 19460       |
# |    policy_gradient_loss | -0.0347     |
# |    std                  | 0.131       |
# |    value_loss           | 0.942       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -67.5       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 975         |
# |    time_elapsed         | 17173       |
# |    total_timesteps      | 499200      |
# | train/                  |             |
# |    approx_kl            | 0.044281833 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.4       |
# |    explained_variance   | -0.174      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.0218      |
# |    n_updates            | 19480       |
# |    policy_gradient_loss | -0.00483    |
# |    std                  | 0.131       |
# |    value_loss           | 0.227       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 997         |
# |    ep_rew_mean          | -67.5       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 976         |
# |    time_elapsed         | 17185       |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.028724173 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -17.2       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.186       |
# |    n_updates            | 19500       |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.131       |
# |    value_loss           | 0.523       |
# -----------------------------------------
# Eval num_timesteps=500000, episode_reward=-82.90 +/- 1.07
# Episode length: 1000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1e+03      |
# |    mean_reward          | -82.9      |
# | time/                   |            |
# |    total_timesteps      | 500000     |
# | train/                  |            |
# |    approx_kl            | 0.03828143 |
# |    clip_fraction        | 0.0771     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -17.1      |
# |    explained_variance   | 0.545      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.132      |
# |    n_updates            | 19520      |
# |    policy_gradient_loss | -0.0123    |
# |    std                  | 0.131      |
# |    value_loss           | 0.61       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 997      |
# |    ep_rew_mean     | -67.1    |
# | time/              |          |
# |    fps             | 29       |
# |    iterations      | 977      |
# |    time_elapsed    | 17238    |
# |    total_timesteps | 500224   |
# ---------------------------------

# %% [markdown]
# Connect to the tensorboard log using **TensorBoard** from the command line to view training progress:
#
# `tensorboard --logdir ./log_tb_carracing_task2_final1/`
#
# Then open TensorBoard in a browser, typically located at:
#
# `http://localhost:6006/`

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %tensorboard --logdir ./log_tb_carracing_task2_final1/
# Out:
#       <iframe id="tensorboard-frame-7d2dfd1142fd87e5" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-7d2dfd1142fd87e5");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Save the trained agent.

# %%
ppo_agent_model.save("./carracingPPO_agent_stack")

# %% [markdown]
# For memory management delete old agent and environment (assumes variable names - change if required).

# %%
del ppo_agent_model
del env
del eval_env

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### Load the single image saved agent

# %%
ppo_agent_model = sb3.ppo.PPO.load("./carracingPPO_agent")

# %% [markdown]
# Setup the single image environment for evaluation.

# %%
eval_env = gym.make('CarRacing-v2', render_mode= "human") # We use a separate evaluation env in case any wrappers have been used
eval_env = gym.wrappers.resize_observation.ResizeObservation(eval_env, 64)
# This wrapper converts RGB images to grayscale, which simplifies the 
# learning task by reducing the color information that the model needs to process. 
eval_env = gym.wrappers.gray_scale_observation.GrayScaleObservation(eval_env, keep_dim = True)

# %% [markdown]
# Evaluate the agent in the environment for 30 episodes, rendering the process.

# %%
ppo_agent_model.set_env(eval_env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
# Add code here
mean_reward, std_reward = sb3.common.evaluation.evaluate_policy(ppo_agent_model, 
                                                                eval_env, 
                                                                n_eval_episodes=30,
                                                               render = True)
print("Mean Reward: {} +/- {}".format(mean_reward, std_reward))
# Out:
# Mean Reward: -82.97379410862922 +/- 1.3005900032994788

# %% [markdown]
# For memory management delete the single image agent (assumes variable names - change if required).

# %%
del ppo_agent_model
del eval_env

# %% [markdown]
# #### Load the image stack agent

# %%
# Add code here 
ppo_agent_model = sb3.ppo.PPO.load("./carracingPPO_agent_stack")

# %% [markdown]
# Set up the image stack environment

# %%
# Add code here
eval_env = gym.make('CarRacing-v2' ,render_mode= "human")
eval_env = gym.wrappers.resize_observation.ResizeObservation(eval_env, 64)
eval_env = gym.wrappers.gray_scale_observation.GrayScaleObservation(eval_env, keep_dim = True)
eval_env = sb3.common.monitor.Monitor(eval_env)
eval_env = sb3.common.vec_env.DummyVecEnv([lambda: eval_env])
eval_env = sb3.common.vec_env.VecFrameStack(eval_env, 
                                       n_stack=4)

# %%
ppo_agent_model.set_env(eval_env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# Evaluate the agent in the environment for 30 episodes, rendering the process.

# %%
# Add code here
# testing model 
episodes = 10
scores_array = []
timestep_arr = []
for episode in range(1, episodes+1):
    obs = eval_env.reset()  #state = env.reset()
    done = False
    score = 0
    timestep = 0
    
    while not done:
        action , _ = ppo_agent_model.predict(obs) 
        obs, reward, done, info = eval_env.step(action) 
        score += reward
        timestep += 1
        eval_env.render()
    scores_array.append(score)
    timestep_arr.append(timestep)
    print("Episode:{} Score:{}".format(episode,score))
eval_env.close()
# Out:
# Episode:1 Score:[-70.32597]
# Episode:2 Score:[-68.84695]
# Episode:3 Score:[-67.845276]
# Episode:4 Score:[-65.03464]
# Episode:5 Score:[-39.799084]
# Episode:6 Score:[-32.584015]
# Episode:7 Score:[-43.52133]
# Episode:8 Score:[-44.61514]
# Episode:9 Score:[-39.79908]
# Episode:10 Score:[-42.307438]

# %%
# Add code here
mean_reward, std_reward = sb3.common.evaluation.evaluate_policy(ppo_agent_model, 
                                                                eval_env, 
                                                                n_eval_episodes=30,
                                                               render = True)
print("Mean Reward: {} +/- {}".format(mean_reward, std_reward))
# Out:
# Mean Reward: -30.90001066666667 +/- 21.29935653787396

# %%
del ppo_agent_model
del eval_env

# %% [markdown]
# ### Training Better Model for Longer

# %%
ppo_agent_model = sb3.ppo.PPO.load("./carracingPPO_agent_stack")

# %%
# Add code here
eval_env = gym.make('CarRacing-v2' ,render_mode= "human")
eval_env = gym.wrappers.resize_observation.ResizeObservation(eval_env, 64)
eval_env = gym.wrappers.gray_scale_observation.GrayScaleObservation(eval_env, keep_dim = True)
eval_env = sb3.common.monitor.Monitor(eval_env)
eval_env = sb3.common.vec_env.DummyVecEnv([lambda: eval_env])
eval_env = sb3.common.vec_env.VecFrameStack(eval_env, 
                                       n_stack=4)

# %%
ppo_agent_model.set_env(eval_env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %%
ppo_agent_model.learn(total_timesteps = 500000, 
            reset_num_timesteps = False)
# Out:
# Logging to ./log_tb_carracing_task2_final1/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -6.45    |
# | time/              |          |
# |    fps             | 45       |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2001408  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.45      |
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 2          |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 2001920    |
# | train/                  |            |
# |    approx_kl            | 0.03934592 |
# |    clip_fraction        | 0.0619     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.6      |
# |    explained_variance   | 0.803      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 1.16       |
# |    n_updates            | 78180      |
# |    policy_gradient_loss | -0.00065   |
# |    std                  | 0.127      |
# |    value_loss           | 2.99       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.99       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 2002432     |
# | train/                  |             |
# |    approx_kl            | 0.014497234 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.638       |
# |    n_updates            | 78200       |
# |    policy_gradient_loss | -0.00111    |
# |    std                  | 0.127       |
# |    value_loss           | 2.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.72       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 4           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 2002944     |
# | train/                  |             |
# |    approx_kl            | 0.026177399 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.8       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.519       |
# |    n_updates            | 78220       |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.127       |
# |    value_loss           | 1.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.72       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 5           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 2003456     |
# | train/                  |             |
# |    approx_kl            | 0.034580432 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.454       |
# |    n_updates            | 78240       |
# |    policy_gradient_loss | -0.00543    |
# |    std                  | 0.127       |
# |    value_loss           | 2.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.49       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 6           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 2003968     |
# | train/                  |             |
# |    approx_kl            | 0.030780721 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.485       |
# |    n_updates            | 78260       |
# |    policy_gradient_loss | -0.00171    |
# |    std                  | 0.127       |
# |    value_loss           | 1.7         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.49      |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 7          |
# |    time_elapsed         | 112        |
# |    total_timesteps      | 2004480    |
# | train/                  |            |
# |    approx_kl            | 0.05912502 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.4      |
# |    explained_variance   | 0.848      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.722      |
# |    n_updates            | 78280      |
# |    policy_gradient_loss | -0.0116    |
# |    std                  | 0.127      |
# |    value_loss           | 1.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.55       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 8           |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 2004992     |
# | train/                  |             |
# |    approx_kl            | 0.051395632 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.811       |
# |    n_updates            | 78300       |
# |    policy_gradient_loss | -0.00552    |
# |    std                  | 0.127       |
# |    value_loss           | 1.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.55       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 9           |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 2005504     |
# | train/                  |             |
# |    approx_kl            | 0.034163266 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.39        |
# |    n_updates            | 78320       |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.127       |
# |    value_loss           | 2.52        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -5.91      |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 10         |
# |    time_elapsed         | 163        |
# |    total_timesteps      | 2006016    |
# | train/                  |            |
# |    approx_kl            | 0.03945925 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.6      |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.162      |
# |    n_updates            | 78340      |
# |    policy_gradient_loss | -0.00608   |
# |    std                  | 0.127      |
# |    value_loss           | 1.09       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -5.91       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 11          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 2006528     |
# | train/                  |             |
# |    approx_kl            | 0.021570569 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.501       |
# |    n_updates            | 78360       |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.127       |
# |    value_loss           | 1.57        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.99      |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 12         |
# |    time_elapsed         | 197        |
# |    total_timesteps      | 2007040    |
# | train/                  |            |
# |    approx_kl            | 0.03469558 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -21        |
# |    explained_variance   | 0.538      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.00751    |
# |    n_updates            | 78380      |
# |    policy_gradient_loss | -0.0217    |
# |    std                  | 0.127      |
# |    value_loss           | 1.01       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.99      |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 13         |
# |    time_elapsed         | 214        |
# |    total_timesteps      | 2007552    |
# | train/                  |            |
# |    approx_kl            | 0.01764285 |
# |    clip_fraction        | 0.0544     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -21        |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.46       |
# |    n_updates            | 78400      |
# |    policy_gradient_loss | -0.00142   |
# |    std                  | 0.127      |
# |    value_loss           | 1.58       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.31       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 14          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 2008064     |
# | train/                  |             |
# |    approx_kl            | 0.042219784 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.803       |
# |    n_updates            | 78420       |
# |    policy_gradient_loss | 0.00327     |
# |    std                  | 0.127       |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.31       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 15          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 2008576     |
# | train/                  |             |
# |    approx_kl            | 0.053368997 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.78        |
# |    n_updates            | 78440       |
# |    policy_gradient_loss | -0.00533    |
# |    std                  | 0.127       |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.97       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 16          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 2009088     |
# | train/                  |             |
# |    approx_kl            | 0.032545447 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.8       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.13        |
# |    n_updates            | 78460       |
# |    policy_gradient_loss | 0.0191      |
# |    std                  | 0.127       |
# |    value_loss           | 1.54        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -6.97     |
# | time/                   |           |
# |    fps                  | 30        |
# |    iterations           | 17        |
# |    time_elapsed         | 282       |
# |    total_timesteps      | 2009600   |
# | train/                  |           |
# |    approx_kl            | 0.3665603 |
# |    clip_fraction        | 0.266     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -20.6     |
# |    explained_variance   | 0.674     |
# |    learning_rate        | 3e-05     |
# |    loss                 | 1.51      |
# |    n_updates            | 78480     |
# |    policy_gradient_loss | 0.0048    |
# |    std                  | 0.127     |
# |    value_loss           | 4.42      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.98      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 18         |
# |    time_elapsed         | 298        |
# |    total_timesteps      | 2010112    |
# | train/                  |            |
# |    approx_kl            | 0.02678211 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.3      |
# |    explained_variance   | 0.655      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.859      |
# |    n_updates            | 78500      |
# |    policy_gradient_loss | 0.0133     |
# |    std                  | 0.127      |
# |    value_loss           | 2.07       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -6.98       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 19          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 2010624     |
# | train/                  |             |
# |    approx_kl            | 0.026868949 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.721       |
# |    n_updates            | 78520       |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.127       |
# |    value_loss           | 1.85        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -7.72     |
# | time/                   |           |
# |    fps                  | 30        |
# |    iterations           | 20        |
# |    time_elapsed         | 333       |
# |    total_timesteps      | 2011136   |
# | train/                  |           |
# |    approx_kl            | 0.0362495 |
# |    clip_fraction        | 0.0771    |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -20.5     |
# |    explained_variance   | 0.839     |
# |    learning_rate        | 3e-05     |
# |    loss                 | 0.735     |
# |    n_updates            | 78540     |
# |    policy_gradient_loss | -0.0146   |
# |    std                  | 0.127     |
# |    value_loss           | 1.83      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.72       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 21          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 2011648     |
# | train/                  |             |
# |    approx_kl            | 0.038791504 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.4       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.77        |
# |    n_updates            | 78560       |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.127       |
# |    value_loss           | 1.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.36       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 22          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 2012160     |
# | train/                  |             |
# |    approx_kl            | 0.058665648 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.7       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.357       |
# |    n_updates            | 78580       |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.127       |
# |    value_loss           | 2           |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.36      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 23         |
# |    time_elapsed         | 385        |
# |    total_timesteps      | 2012672    |
# | train/                  |            |
# |    approx_kl            | 0.03944777 |
# |    clip_fraction        | 0.0794     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.5      |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.744      |
# |    n_updates            | 78600      |
# |    policy_gradient_loss | -0.012     |
# |    std                  | 0.127      |
# |    value_loss           | 2.35       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.62      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 24         |
# |    time_elapsed         | 402        |
# |    total_timesteps      | 2013184    |
# | train/                  |            |
# |    approx_kl            | 0.05729849 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.4      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.64       |
# |    n_updates            | 78620      |
# |    policy_gradient_loss | -0.0301    |
# |    std                  | 0.127      |
# |    value_loss           | 1.64       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -7.62        |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 25           |
# |    time_elapsed         | 419          |
# |    total_timesteps      | 2013696      |
# | train/                  |              |
# |    approx_kl            | 0.0146258455 |
# |    clip_fraction        | 0.23         |
# |    clip_range           | 0.4          |
# |    entropy_loss         | -20.4        |
# |    explained_variance   | 0.538        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 1.05         |
# |    n_updates            | 78640        |
# |    policy_gradient_loss | 0.0386       |
# |    std                  | 0.127        |
# |    value_loss           | 2.58         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.13       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 26          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 2014208     |
# | train/                  |             |
# |    approx_kl            | 0.033157054 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.414       |
# |    n_updates            | 78660       |
# |    policy_gradient_loss | -0.00743    |
# |    std                  | 0.127       |
# |    value_loss           | 0.59        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.13      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 27         |
# |    time_elapsed         | 454        |
# |    total_timesteps      | 2014720    |
# | train/                  |            |
# |    approx_kl            | 0.04693144 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.6      |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.19       |
# |    n_updates            | 78680      |
# |    policy_gradient_loss | -0.0352    |
# |    std                  | 0.127      |
# |    value_loss           | 0.741      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.91       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 28          |
# |    time_elapsed         | 471         |
# |    total_timesteps      | 2015232     |
# | train/                  |             |
# |    approx_kl            | 0.026102226 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.9       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.126       |
# |    n_updates            | 78700       |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.127       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.91       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 29          |
# |    time_elapsed         | 489         |
# |    total_timesteps      | 2015744     |
# | train/                  |             |
# |    approx_kl            | 0.029989593 |
# |    clip_fraction        | 0.0895      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.387       |
# |    n_updates            | 78720       |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.127       |
# |    value_loss           | 1.04        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -9.24    |
# | time/                   |          |
# |    fps                  | 30       |
# |    iterations           | 30       |
# |    time_elapsed         | 506      |
# |    total_timesteps      | 2016256  |
# | train/                  |          |
# |    approx_kl            | 1.182153 |
# |    clip_fraction        | 0.39     |
# |    clip_range           | 0.4      |
# |    entropy_loss         | -20.5    |
# |    explained_variance   | 0.888    |
# |    learning_rate        | 3e-05    |
# |    loss                 | 0.273    |
# |    n_updates            | 78740    |
# |    policy_gradient_loss | 0.0049   |
# |    std                  | 0.127    |
# |    value_loss           | 0.537    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -9.24       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 31          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 2016768     |
# | train/                  |             |
# |    approx_kl            | 0.022657376 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 2.02        |
# |    n_updates            | 78760       |
# |    policy_gradient_loss | 0.00232     |
# |    std                  | 0.127       |
# |    value_loss           | 5.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.82       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 32          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 2017280     |
# | train/                  |             |
# |    approx_kl            | 0.048038185 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.3       |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.472       |
# |    n_updates            | 78780       |
# |    policy_gradient_loss | -0.00539    |
# |    std                  | 0.127       |
# |    value_loss           | 0.826       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.82      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 33         |
# |    time_elapsed         | 558        |
# |    total_timesteps      | 2017792    |
# | train/                  |            |
# |    approx_kl            | 0.02958095 |
# |    clip_fraction        | 0.166      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.2      |
# |    explained_variance   | 0.532      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 1.65       |
# |    n_updates            | 78800      |
# |    policy_gradient_loss | -0.023     |
# |    std                  | 0.127      |
# |    value_loss           | 4.74       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.72      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 34         |
# |    time_elapsed         | 575        |
# |    total_timesteps      | 2018304    |
# | train/                  |            |
# |    approx_kl            | 0.11829176 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.1      |
# |    explained_variance   | 0.368      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.739      |
# |    n_updates            | 78820      |
# |    policy_gradient_loss | -0.0255    |
# |    std                  | 0.127      |
# |    value_loss           | 1.99       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.72      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 35         |
# |    time_elapsed         | 593        |
# |    total_timesteps      | 2018816    |
# | train/                  |            |
# |    approx_kl            | 0.03154946 |
# |    clip_fraction        | 0.0919     |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.1      |
# |    explained_variance   | 0.725      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 1.35       |
# |    n_updates            | 78840      |
# |    policy_gradient_loss | 0.00298    |
# |    std                  | 0.127      |
# |    value_loss           | 3.7        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.97       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 36          |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 2019328     |
# | train/                  |             |
# |    approx_kl            | 0.112463534 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.348       |
# |    n_updates            | 78860       |
# |    policy_gradient_loss | -0.0381     |
# |    std                  | 0.127       |
# |    value_loss           | 1.45        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -8.97      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 37         |
# |    time_elapsed         | 628        |
# |    total_timesteps      | 2019840    |
# | train/                  |            |
# |    approx_kl            | 0.14289284 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.1      |
# |    explained_variance   | 0.803      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.954      |
# |    n_updates            | 78880      |
# |    policy_gradient_loss | -0.033     |
# |    std                  | 0.127      |
# |    value_loss           | 2.61       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.98       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 38          |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 2020352     |
# | train/                  |             |
# |    approx_kl            | 0.053262584 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.55        |
# |    n_updates            | 78900       |
# |    policy_gradient_loss | -0.0045     |
# |    std                  | 0.127       |
# |    value_loss           | 0.958       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.98       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 39          |
# |    time_elapsed         | 663         |
# |    total_timesteps      | 2020864     |
# | train/                  |             |
# |    approx_kl            | 0.010001425 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.3       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.05        |
# |    n_updates            | 78920       |
# |    policy_gradient_loss | -0.00251    |
# |    std                  | 0.127       |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.43       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 40          |
# |    time_elapsed         | 680         |
# |    total_timesteps      | 2021376     |
# | train/                  |             |
# |    approx_kl            | 0.015453092 |
# |    clip_fraction        | 0.0802      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.87        |
# |    n_updates            | 78940       |
# |    policy_gradient_loss | -0.00425    |
# |    std                  | 0.127       |
# |    value_loss           | 3.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.43       |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 41          |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 2021888     |
# | train/                  |             |
# |    approx_kl            | 0.040122736 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.464       |
# |    n_updates            | 78960       |
# |    policy_gradient_loss | 0.00395     |
# |    std                  | 0.127       |
# |    value_loss           | 1.28        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.4       |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 42         |
# |    time_elapsed         | 715        |
# |    total_timesteps      | 2022400    |
# | train/                  |            |
# |    approx_kl            | 0.11847405 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20        |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.487      |
# |    n_updates            | 78980      |
# |    policy_gradient_loss | 0.00255    |
# |    std                  | 0.127      |
# |    value_loss           | 1.56       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.4       |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 43         |
# |    time_elapsed         | 733        |
# |    total_timesteps      | 2022912    |
# | train/                  |            |
# |    approx_kl            | 0.03948217 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.1      |
# |    explained_variance   | 0.687      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 1.08       |
# |    n_updates            | 79000      |
# |    policy_gradient_loss | 0.0191     |
# |    std                  | 0.127      |
# |    value_loss           | 3.47       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -7.24     |
# | time/                   |           |
# |    fps                  | 30        |
# |    iterations           | 44        |
# |    time_elapsed         | 750       |
# |    total_timesteps      | 2023424   |
# | train/                  |           |
# |    approx_kl            | 0.0256733 |
# |    clip_fraction        | 0.084     |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -20.3     |
# |    explained_variance   | 0.919     |
# |    learning_rate        | 3e-05     |
# |    loss                 | 0.379     |
# |    n_updates            | 79020     |
# |    policy_gradient_loss | -0.0101   |
# |    std                  | 0.127     |
# |    value_loss           | 1.31      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -6.93      |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 45         |
# |    time_elapsed         | 767        |
# |    total_timesteps      | 2023936    |
# | train/                  |            |
# |    approx_kl            | 0.04710317 |
# |    clip_fraction        | 0.138      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.2      |
# |    explained_variance   | 0.795      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.632      |
# |    n_updates            | 79040      |
# |    policy_gradient_loss | -0.0314    |
# |    std                  | 0.127      |
# |    value_loss           | 2.18       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -6.93     |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 46        |
# |    time_elapsed         | 785       |
# |    total_timesteps      | 2024448   |
# | train/                  |           |
# |    approx_kl            | 0.0525826 |
# |    clip_fraction        | 0.34      |
# |    clip_range           | 0.4       |
# |    entropy_loss         | -20.1     |
# |    explained_variance   | 0.637     |
# |    learning_rate        | 3e-05     |
# |    loss                 | 0.48      |
# |    n_updates            | 79060     |
# |    policy_gradient_loss | 0.0035    |
# |    std                  | 0.127     |
# |    value_loss           | 2.12      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -7.17      |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 47         |
# |    time_elapsed         | 802        |
# |    total_timesteps      | 2024960    |
# | train/                  |            |
# |    approx_kl            | 0.27357274 |
# |    clip_fraction        | 0.134      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.6      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.159      |
# |    n_updates            | 79080      |
# |    policy_gradient_loss | 0.0107     |
# |    std                  | 0.127      |
# |    value_loss           | 0.463      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.17       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 48          |
# |    time_elapsed         | 820         |
# |    total_timesteps      | 2025472     |
# | train/                  |             |
# |    approx_kl            | 0.009807591 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.184       |
# |    n_updates            | 79100       |
# |    policy_gradient_loss | -0.0284     |
# |    std                  | 0.127       |
# |    value_loss           | 0.573       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7          |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 49          |
# |    time_elapsed         | 837         |
# |    total_timesteps      | 2025984     |
# | train/                  |             |
# |    approx_kl            | 0.065581724 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.1       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.782       |
# |    n_updates            | 79120       |
# |    policy_gradient_loss | 0.0039      |
# |    std                  | 0.127       |
# |    value_loss           | 2.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7          |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 50          |
# |    time_elapsed         | 855         |
# |    total_timesteps      | 2026496     |
# | train/                  |             |
# |    approx_kl            | 0.029138511 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.3       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.794       |
# |    n_updates            | 79140       |
# |    policy_gradient_loss | -0.0195     |
# |    std                  | 0.127       |
# |    value_loss           | 2.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.25       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 51          |
# |    time_elapsed         | 872         |
# |    total_timesteps      | 2027008     |
# | train/                  |             |
# |    approx_kl            | 0.060773093 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.218       |
# |    n_updates            | 79160       |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.127       |
# |    value_loss           | 0.898       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.25       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 52          |
# |    time_elapsed         | 890         |
# |    total_timesteps      | 2027520     |
# | train/                  |             |
# |    approx_kl            | 0.024572097 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.253       |
# |    n_updates            | 79180       |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.127       |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -7.47       |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 53          |
# |    time_elapsed         | 907         |
# |    total_timesteps      | 2028032     |
# | train/                  |             |
# |    approx_kl            | 0.034772012 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.2       |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.323       |
# |    n_updates            | 79200       |
# |    policy_gradient_loss | -0.0213     |
# |    std                  | 0.127       |
# |    value_loss           | 1.19        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | -7.47    |
# ...
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.5      |
# |    explained_variance   | 0.895      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.596      |
# |    n_updates            | 97340      |
# |    policy_gradient_loss | -0.000121  |
# |    std                  | 0.127      |
# |    value_loss           | 1.5        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.43       |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 961        |
# |    time_elapsed         | 18422      |
# |    total_timesteps      | 2492928    |
# | train/                  |            |
# |    approx_kl            | 0.13168997 |
# |    clip_fraction        | 0.599      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.4      |
# |    explained_variance   | 0.746      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 1.02       |
# |    n_updates            | 97360      |
# |    policy_gradient_loss | 0.0419     |
# |    std                  | 0.127      |
# |    value_loss           | 3.04       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 4.43        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 962         |
# |    time_elapsed         | 18440       |
# |    total_timesteps      | 2493440     |
# | train/                  |             |
# |    approx_kl            | 0.121385604 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.8       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.475       |
# |    n_updates            | 97380       |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.127       |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 4.66        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 963         |
# |    time_elapsed         | 18457       |
# |    total_timesteps      | 2493952     |
# | train/                  |             |
# |    approx_kl            | 0.012869889 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.9       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.212       |
# |    n_updates            | 97400       |
# |    policy_gradient_loss | -0.00573    |
# |    std                  | 0.127       |
# |    value_loss           | 0.766       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 4.66       |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 964        |
# |    time_elapsed         | 18475      |
# |    total_timesteps      | 2494464    |
# | train/                  |            |
# |    approx_kl            | 0.04639195 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.6      |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.566      |
# |    n_updates            | 97420      |
# |    policy_gradient_loss | -0.0115    |
# |    std                  | 0.127      |
# |    value_loss           | 2.15       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.9        |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 965        |
# |    time_elapsed         | 18493      |
# |    total_timesteps      | 2494976    |
# | train/                  |            |
# |    approx_kl            | 0.02599988 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.6      |
# |    explained_variance   | 0.609      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.402      |
# |    n_updates            | 97440      |
# |    policy_gradient_loss | -0.00379   |
# |    std                  | 0.127      |
# |    value_loss           | 1.75       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.9         |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 966         |
# |    time_elapsed         | 18510       |
# |    total_timesteps      | 2495488     |
# | train/                  |             |
# |    approx_kl            | 0.061224222 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.7       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.363       |
# |    n_updates            | 97460       |
# |    policy_gradient_loss | -0.029      |
# |    std                  | 0.127       |
# |    value_loss           | 1.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.82        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 967         |
# |    time_elapsed         | 18527       |
# |    total_timesteps      | 2496000     |
# | train/                  |             |
# |    approx_kl            | 0.060808517 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.7       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.337       |
# |    n_updates            | 97480       |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.127       |
# |    value_loss           | 1.23        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.82        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 968         |
# |    time_elapsed         | 18545       |
# |    total_timesteps      | 2496512     |
# | train/                  |             |
# |    approx_kl            | 0.054418795 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.8       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.319       |
# |    n_updates            | 97500       |
# |    policy_gradient_loss | -0.0229     |
# |    std                  | 0.127       |
# |    value_loss           | 1.49        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 1.58       |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 969        |
# |    time_elapsed         | 18563      |
# |    total_timesteps      | 2497024    |
# | train/                  |            |
# |    approx_kl            | 0.03818974 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -20.6      |
# |    explained_variance   | 0.799      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.766      |
# |    n_updates            | 97520      |
# |    policy_gradient_loss | -0.0537    |
# |    std                  | 0.127      |
# |    value_loss           | 2.35       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 1.58        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 970         |
# |    time_elapsed         | 18580       |
# |    total_timesteps      | 2497536     |
# | train/                  |             |
# |    approx_kl            | 0.019276403 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.54        |
# |    n_updates            | 97540       |
# |    policy_gradient_loss | -0.00201    |
# |    std                  | 0.127       |
# |    value_loss           | 2.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.65        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 971         |
# |    time_elapsed         | 18598       |
# |    total_timesteps      | 2498048     |
# | train/                  |             |
# |    approx_kl            | 0.022160908 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.65        |
# |    n_updates            | 97560       |
# |    policy_gradient_loss | 0.00598     |
# |    std                  | 0.127       |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 2.65        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 972         |
# |    time_elapsed         | 18616       |
# |    total_timesteps      | 2498560     |
# | train/                  |             |
# |    approx_kl            | 0.060036547 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.6       |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.04        |
# |    n_updates            | 97580       |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.127       |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.21        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 973         |
# |    time_elapsed         | 18633       |
# |    total_timesteps      | 2499072     |
# | train/                  |             |
# |    approx_kl            | 0.035025645 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.5       |
# |    explained_variance   | 0.674       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 2.43        |
# |    n_updates            | 97600       |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.127       |
# |    value_loss           | 5.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.21        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 974         |
# |    time_elapsed         | 18651       |
# |    total_timesteps      | 2499584     |
# | train/                  |             |
# |    approx_kl            | 0.018862639 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.7       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.749       |
# |    n_updates            | 97620       |
# |    policy_gradient_loss | -0.00848    |
# |    std                  | 0.127       |
# |    value_loss           | 2.78        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 3.36        |
# | time/                   |             |
# |    fps                  | 26          |
# |    iterations           | 975         |
# |    time_elapsed         | 18669       |
# |    total_timesteps      | 2500096     |
# | train/                  |             |
# |    approx_kl            | 0.029739153 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.4         |
# |    entropy_loss         | -20.8       |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.26        |
# |    n_updates            | 97640       |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.127       |
# |    value_loss           | 2.88        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 3.36       |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 976        |
# |    time_elapsed         | 18686      |
# |    total_timesteps      | 2500608    |
# | train/                  |            |
# |    approx_kl            | 0.09709795 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -21.1      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.0958     |
# |    n_updates            | 97660      |
# |    policy_gradient_loss | 0.00969    |
# |    std                  | 0.127      |
# |    value_loss           | 0.813      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 2.93       |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 977        |
# |    time_elapsed         | 18704      |
# |    total_timesteps      | 2501120    |
# | train/                  |            |
# |    approx_kl            | 0.05767467 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.4        |
# |    entropy_loss         | -21        |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 3e-05      |
# |    loss                 | 0.286      |
# |    n_updates            | 97680      |
# |    policy_gradient_loss | -0.00232   |
# |    std                  | 0.127      |
# |    value_loss           | 1.13       |
# ----------------------------------------

# %%
ppo_agent_model.save("./carracingPPO_agent_stack")

# %% [markdown]
# ### Reflection

# %% [markdown]
# Reflect on which  agent performs better at the task, and the training process involved (max 200 words).

# %% [markdown]
# Initially, my model, trained over 500,000 timesteps, showed poor performance with both single and stacked image agents yielding low rewards.
#
# ##### Results on 500000 timesteps
# 1. My evaluation for single image agent [Mean Reward: -92.95956816666668 +/- 0.7243045979982494].
# 2. My evaluation for stack image agent [Mean Reward: -83.51077016666666 +/- 1.5817448422319385].
#
# ##### Which agent performed better (1000000 timesteps)?
# Upon increasing the timesteps to 1,000,000, the stacked image agent slightly outperformed the single image agent, demonstrating better mean rewards. My stacked image agent performed better.
#
# 1. My evaluation for single image agent [Mean Reward: -82.97379410862922 +/- 1.3005900032994788]
# 2. My evaluation for stack image agent[ Mean Reward: -80.95164756666667 +/- 1.6859319366412475]
#
# Subsequent training of the stacked image agent for 2,500,000 timesteps significantly improved its performance, achieving a mean reward of -30.90 with a higher standard deviation, indicating varying performance across episodes. The extensive training required considerable computational resources and time, often needing overnight runs, which slowed down the ability to make and test adjustments rapidly.  [Mean Reward: -30.90001066666667 +/- 21.29935653787396]
#
# ##### Considerations for the future
# 1. balancing exploration and exploitation remains a crucial challenge in RL.
# 2. Techniques such as pixel normalization and reward standardization could be implemented to manage the broad range of reward values and reduce the dimensionality of the observation space, potentially enhancing model performance.
# 3. Longer training times. More training results in better performance.
# 4. Better computation power. CPU constraints.
#
# ##### References
# 1. https://agents.inf.ed.ac.uk/blog/reinforcement-learning-implementation-tricks/#:~:text=Frame%20stacking,obtained%20from%20a%20single%20image.
# 2. https://towardsdatascience.com/reinforcement-learning-101-e24b50e1d292
# 3. https://www.fool.com/terms/r/reinforcement-learning/#:~:text=Of%20course%2C%20there%20are%20downsides,of%20the%20positive%20value%20description.
